# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Quang\Downloads\Stt,Mã Cổ phiếu,Tên Công ty,Khối lư.csv", sep='\t')
print(df.columns)
# Out:
# Index(['Z-score volume', 'Z-score TVL', 'Z-score Fees', 'Z-score SC',
#        'Total pont'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import os

data = {
    "Volume": [50_196_568, 43_249_334, 12_244_019, 7_503_815, 10_530_737, 8_549_425, 11_528_120, 10_434_687, 5_033_030, 3_534_110],
    "TVL": [3_861_000, 1_604_000, 1_077_000, 1_601_000, 682_580, 796_020, 233_460, 21_000, 34_170, 92_360],
    "Cumulative Volume": [1_572_000_000, 1_170_000_000, 487_702_000, 244_200_000, 175_906_000, 164_354_000, 289_521_000, 31_590_000, 29_400_000, 28_697_000],
    "Fees": [33, 9, 1, 3, 1, 1, 2, 9, 1, 1],
    "Multi-chain": [33, 9, 1, 3, 1, 1, 2, 9, 1, 1],
    "Point": [2.2662, 1.1264, -0.1042, -0.1572, -0.3654, -0.3885, 0.407, -0.5108, -0.7217, -0.7424]}

df = pd.DataFrame(data, index=[
    "Uniswap", "PancakeSwap", "Raydium", "Curve Finance", "Meteora",
    "Aerodrome", "Orca", "Fluid", "Pump", "Hyperliquid"])

correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation of raw values")
home_dir = os.path.expanduser("~")
download_path = os.path.join(home_dir, "Downloads", "correlation_heatmap_raw_values.png")
plt.savefig(download_path, dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Dữ liệu Total Points
total_points = [2.2662, 1.1264, -0.1042, -0.1572, -0.3654, -0.3885, -0.4024, -0.5108, -0.7217, -0.7424]

# Vẽ biểu đồ phân phối
plt.figure(figsize=(8, 6))
sns.histplot(total_points, kde=True, bins=10, color='blue')

# Thêm tiêu đề và nhãn cho trục
plt.title('Distribution Total point', fontsize=16)
plt.xlabel('Total Points', fontsize=12)
plt.ylabel('Tần suất', fontsize=12)

home_dir = os.path.expanduser("~")
download_path = os.path.join(home_dir, "Downloads", "cof")
plt.savefig(download_path, dpi=300, bbox_inches='tight')

# Hiển thị biểu đồ
plt.show()
